# %% [markdown]
# <a href="https://colab.research.google.com/github/jx1100370217/JXNMT/blob/master/NMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jx1100370217/JXNMT.git

# %%
cd JXNMT/

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git

# %%
# !bash 1_punctuation.sh

# %%
# !bash 2_tokenizer.sh

# %%
# !bash 3_truecase.sh

# %%
# !bash 4_jieba.sh

# %%
# !bash 5_clean-corpus-n.sh

# %%
# !bash 6_sets_split.sh

# %%
# !bash 7_datagen.sh

# %%
# !bash train.sh
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0928 05:38:03.302979 140297574492032 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0928 05:38:03.945163 140297574492032 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0928 05:38:05.574043 140297574492032 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/tensor2tensor/utils/adafactor.py:27: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# ...
